# %%
import pandas as pd;
import numpy as np;

# %%
data = pd.read_csv('../data/rshot.csv.TXT', delimiter=';', low_memory=False)

# %%
data.columns = data.columns.str.replace(' ', '')
data.columns = data.columns.str.replace('#', 'Nr')
data.columns = data.columns.str.replace('.', '')
data.columns
# Out:
# Index(['TourCode', 'TourDescription', 'Year', 'TournNr', 'PlayerNr',
#        'CourseNr', 'PermanentTournamentNr', 'PlayerFirstName',
#        'PlayerLastName', 'Round', 'TournamentName', 'CourseName', 'Hole',
#        'HoleScore', 'ParValue', 'Yardage', 'Shot', 'ShotType(S/P/D)',
#        'NrofStrokes', 'FromLocation(Scorer)', 'FromLocation(Enhanced)',
#        'ToLocation(Scorer)', 'ToLocation(Enhanced)', 'Distance',
#        'DistancetoPin', 'IntheHoleFlag', 'AroundtheGreenFlag', '1stPuttFlag',
#        'DistancetoHoleaftertheShot', 'Time', 'Lie', 'Elevation', 'Slope',
#        'XCoordinate', 'YCoordinate', 'ZCoordinate', 'DistancefromCenter',
#        'DistancefromEdge', 'Date', 'Left/Right', 'StrokesGained/Baseline',
#        'StrokesGainedCategory', 'RecoveryShot'],
#       dtype='object')

# %%
data['FromLocation(Enhanced)'].unique()
# Out:
# array([nan, 'Right Rough', 'Unmapped', 'Left Fairway', 'Left Rough',
#        'Right Intermediate', 'Left Intermediate', 'Right Fairway',
#        'Right Front Green Side Bunker', 'Front Center Green Side Bunker',
#        'Front Left Green Side Bunker', 'Left Green Side Bunker',
#        'Right Green Side Bunker', 'Rear Green Side Bunker',
#        'Right Rear Green Side Bunker', 'Left Rear Green Side Bunker'],
#       dtype=object)

# %%
data['is_rough'] =  ~data['FromLocation(Scorer)'].isna() & data['FromLocation(Scorer)'].str.contains('Rough')

# %%
data['is_fairway'] =  ~data['FromLocation(Enhanced)'].isna() & ( data['FromLocation(Enhanced)'].str.contains('Fairway') |  data['FromLocation(Enhanced)'].str.contains('Enhanced') ) & ~data.s

# %%
data = data[data.DistancetoPin > 0]

# %%
# Remove pair tournament with invalid data
data = data[data['TournamentName'] != 'Zurich Classic of New Orleans']
#Remove match play tournament
data = data[~data['TournamentName'].str.contains('Match Play')]

# %%
rough_shots = data[data['is_rough']]
fairway_shots = data[data['is_fairway']]

# %%
rough_sg = rough_shots.groupby('CourseName').describe()['StrokesGained/Baseline'][['mean', 'count', 'std']]

# %%
fairway_sg = fairway_shots.groupby('CourseName').describe()['StrokesGained/Baseline'][['mean', 'count', 'std']]

# %%
sg_mean = pd.concat([fairway_sg_mean, rough_sg_mean], axis=1)

# %%
sg_mean.columns = ['fairway_mean', 'fairway_count', 'fairway_std', 'rough_mean', 'rough_count', 'rough_std']

# %%
all_rough_mean = rough_shots['StrokesGained/Baseline'].mean()
all_fairway_mean = fairway_shots['StrokesGained/Baseline'].mean()
sg_mean['rough_mean'] = sg_mean['rough_mean'] - all_rough_mean
sg_mean['fairway_mean'] = sg_mean['fairway_mean'] - all_fairway_mean
sg_mean['diff'] = sg_mean['rough_mean'] - sg_mean['fairway_mean']

# %%
import scipy.stats as stats

# %%
def two_sample_ttest(row):
    statistic, p_val = stats.ttest_ind_from_stats(row['fairway_mean'],
                                                  row['fairway_std'],
                                                  row['fairway_count'],
                                                  row['rough_mean'],
                                                  row['rough_std'],
                                                  row['rough_count'],
                                                  equal_var = False)
    return p_val

sg_mean['p_val'] = sg_mean.apply(two_sample_ttest, axis=1)

# %%
alpha = 0.05
sg_mean['significant'] = sg_mean['p_val'] < alpha
sg_mean.sort_values('diff')
# Out:
#                                 fairway_mean  fairway_count  fairway_std  \
# CourseName
# East Lake GC                        0.066746         1155.0     0.331132
# Muirfield Village GC                0.019369         5071.0     0.383785
# Bellerive CC                        0.046417         6053.0     0.320432
# TPC Southwind                       0.013335         4884.0     0.347120
# TPC Potomac at Avenel Farm          0.044736         4194.0     0.358094
# TPC Deere Run                       0.032639         5967.0     0.358606
# Sedgefield CC                       0.047738         5103.0     0.331837
# Bay Hill Club & Lodge              -0.016333         5734.0     0.352645
# Ridgewood CC                        0.020935         5019.0     0.326481
# Firestone CC (South)                0.025039         2667.0     0.353135
# Waialae CC                          0.045812         4460.0     0.325439
# Colonial CC                         0.015359         4140.0     0.360585
# The Old White TPC                   0.048619         5157.0     0.318837
# TPC River Highlands                -0.010367         5698.0     0.359766
# Aronimink GC                        0.034934         3420.0     0.322207
# TPC Boston                          0.011540         4267.0     0.363226
# Keene Trace Golf Club               0.037870         4759.0     0.359135
# Torrey Pines GC (South)            -0.014692         3120.0     0.345788
# Sea Island Resort (Seaside)        -0.008449         4029.0     0.328425
# TPC Sawgrass                       -0.010973         5588.0     0.362772
# Club de Golf Chapultepec            0.026979         2511.0     0.359008
# TPC Scottsdale                     -0.000562         4450.0     0.357877
# Silverado Resort and Spa North     -0.025138         4537.0     0.338601
# Stadium Course                      0.007029         2461.0     0.352822
# Innisbrook Resort (Copperhead)     -0.031093         4730.0     0.324760
# CC of Jackson                      -0.034931         4986.0     0.327473
# Glen Abbey GC                      -0.030891         4582.0     0.397019
# Quail Hollow Club                  -0.031299         5000.0     0.348270
# PGA National (Champion)            -0.059832         5020.0     0.376509
# Plantation Course at Kapalua       -0.034526         1831.0     0.366525
# TPC Summerlin                      -0.069081         5082.0     0.375937
# Pebble Beach GL                    -0.056907         2947.0     0.368734
# Trinity Forest Golf Club            0.016141         7213.0     0.340789
# Riviera CC                         -0.022264         5260.0     0.339394
# TPC San Antonio - AT&T Oaks        -0.063587         5866.0     0.359280
# Harbour Town GL                    -0.014494         5787.0     0.352003
# GC of Houston                       0.016623         5883.0     0.335163
#
#                                 rough_mean  rough_count  rough_std      diff  \
# CourseName
# East Lake GC                     -0.059045       1042.0   0.338802 -0.125792
# Muirfield Village GC             -0.054591       2977.0   0.386643 -0.073960
# Bellerive CC                     -0.027218       2590.0   0.360528 -0.073635
# TPC Southwind                    -0.057463       4077.0   0.381274 -0.070797
# TPC Potomac at Avenel Farm       -0.015418       3132.0   0.359574 -0.060153
# TPC Deere Run                    -0.026956       2575.0   0.354337 -0.059595
# Sedgefield CC                    -0.006151       3117.0   0.349761 -0.053889
# Bay Hill Club & Lodge            -0.065948       1893.0   0.370427 -0.049615
# Ridgewood CC                     -0.017918       2859.0   0.338498 -0.038854
# Firestone CC (South)             -0.013633       2979.0   0.365690 -0.038672
# Waialae CC                        0.017050       2877.0   0.351160 -0.028762
# Colonial CC                      -0.013320       2955.0   0.385437 -0.028679
# The Old White TPC                 0.022655       3371.0   0.342457 -0.025964
# TPC River Highlands              -0.036022       2627.0   0.374326 -0.025656
# Aronimink GC                      0.009701       1443.0   0.351265 -0.025233
# TPC Boston                       -0.008891       2239.0   0.387499 -0.020431
# Keene Trace Golf Club             0.026245       3386.0   0.382209 -0.011625
# Torrey Pines GC (South)          -0.021252       3265.0   0.344740 -0.006561
# Sea Island Resort (Seaside)      -0.009678       1321.0   0.364662 -0.001229
# TPC Sawgrass                     -0.011330       2249.0   0.400910 -0.000357
# Club de Golf Chapultepec          0.039372       2593.0   0.370504  0.012394
# TPC Scottsdale                    0.013874       2632.0   0.359486  0.014436
# Silverado Resort and Spa North   -0.010569       4306.0   0.342899  0.014569
# Stadium Course                    0.024499       2652.0   0.383602  0.017471
# Innisbrook Resort (Copperhead)   -0.009847       4197.0   0.328367  0.021246
# CC of Jackson                    -0.004539       3756.0   0.347239  0.030392
# Glen Abbey GC                     0.005126       4600.0   0.376443  0.036017
# Quail Hollow Club                 0.012688       3811.0   0.355003  0.043987
# PGA National (Champion)          -0.015214       3572.0   0.380834  0.044618
# Plantation Course at Kapalua      0.011195        964.0   0.362235  0.045720
# TPC Summerlin                    -0.017231       3510.0   0.389341  0.051850
# Pebble Beach GL                   0.002458       1596.0   0.378693  0.059364
# Trinity Forest Golf Club          0.076934        699.0   0.352778  0.060793
# Riviera CC                        0.052232       3890.0   0.351422  0.074496
# TPC San Antonio - AT&T Oaks       0.028054       3212.0   0.376039  0.091641
# Harbour Town GL                   0.085013       2194.0   0.384937  0.099507
# GC of Houston                     0.128316       2420.0   0.366181  0.111693
#
#                                        p_val  significant
# CourseName
# East Lake GC                    3.155329e-18         True
# Muirfield Village GC            1.190227e-16         True
# Bellerive CC                    3.725628e-19         True
# TPC Southwind                   9.702693e-20         True
# TPC Potomac at Avenel Farm      1.413183e-12         True
# TPC Deere Run                   1.353315e-12         True
# Sedgefield CC                   5.335104e-12         True
# Bay Hill Club & Lodge           3.369506e-07         True
# Ridgewood CC                    7.180647e-07         True
# Firestone CC (South)            5.426539e-05         True
# Waialae CC                      4.280492e-04         True
# Colonial CC                     1.514679e-03         True
# The Old White TPC               4.393180e-04         True
# TPC River Highlands             3.277401e-03         True
# Aronimink GC                    1.914521e-02         True
# TPC Boston                      3.907947e-02         True
# Keene Trace Golf Club           1.654706e-01        False
# Torrey Pines GC (South)         4.479134e-01        False
# Sea Island Resort (Seaside)     9.133274e-01        False
# TPC Sawgrass                    9.707619e-01        False
# Club de Golf Chapultepec        2.249048e-01        False
# TPC Scottsdale                  1.019416e-01        False
# Silverado Resort and Spa North  4.454083e-02         True
# Stadium Course                  8.988292e-02        False
# Innisbrook Resort (Copperhead)  2.169586e-03         True
# CC of Jackson                   3.347494e-05         True
# Glen Abbey GC                   8.285512e-06         True
# Quail Hollow Club               6.501486e-09         True
# PGA National (Champion)         7.773649e-08         True
# Plantation Course at Kapalua    1.607717e-03         True
# TPC Summerlin                   7.968223e-10         True
# Pebble Beach GL                 3.775955e-07         True
# Trinity Forest Golf Club        1.444122e-05         True
# Riviera CC                      3.714041e-24         True
# TPC San Antonio - AT&T Oaks     3.199106e-29         True
# Harbour Town GL                 1.170643e-25         True
# GC of Houston                   1.400772e-37         True

# %%
rough_shots['StrokesGained/Baseline'].mean()
# Out:
# -0.021018295390913013

# %%
fairway_shots['StrokesGained/Baseline'].mean()
# Out:
# 0.016497696153139056

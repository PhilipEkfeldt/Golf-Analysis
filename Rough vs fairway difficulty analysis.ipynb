# %% [markdown]
# # Rough vs fairway difficulty analysis for the 2017-2018 PGA Tour Season
# Data courtesy of PGA Tour Shotlink. The data contains every shot recorded by the PGA Tours Shotlink system over the 2017-2018 PGA Tour season, together with a strokes gained value for each shot.

# %%
import pandas as pd;
import numpy as np;

# %% [markdown]
# Read in data:

# %%
data = pd.read_csv('../data/rshot.csv.TXT', delimiter=';', low_memory=False)

# %% [markdown]
# Rename columns for easier reading

# %%
data.columns = data.columns.str.replace(' ', '')
data.columns = data.columns.str.replace('#', 'Nr')
data.columns = data.columns.str.replace('.', '')
data.columns
# Out:
# Index(['TourCode', 'TourDescription', 'Year', 'TournNr', 'PlayerNr',
#        'CourseNr', 'PermanentTournamentNr', 'PlayerFirstName',
#        'PlayerLastName', 'Round', 'TournamentName', 'CourseName', 'Hole',
#        'HoleScore', 'ParValue', 'Yardage', 'Shot', 'ShotType(S/P/D)',
#        'NrofStrokes', 'FromLocation(Scorer)', 'FromLocation(Enhanced)',
#        'ToLocation(Scorer)', 'ToLocation(Enhanced)', 'Distance',
#        'DistancetoPin', 'IntheHoleFlag', 'AroundtheGreenFlag', '1stPuttFlag',
#        'DistancetoHoleaftertheShot', 'Time', 'Lie', 'Elevation', 'Slope',
#        'XCoordinate', 'YCoordinate', 'ZCoordinate', 'DistancefromCenter',
#        'DistancefromEdge', 'Date', 'Left/Right', 'StrokesGained/Baseline',
#        'StrokesGainedCategory', 'RecoveryShot'],
#       dtype='object')

# %% [markdown]
# Check what locations are possible:

# %%
data['FromLocation(Scorer)'].unique()
# Out:
# array(['Tee Box', 'Primary Rough', 'Green', 'Fairway', 'Fairway Bunker',
#        'Intermediate Rough', 'Fringe', 'Green Side Bunker', 'Unknown',
#        'Native Area', 'Other', nan, 'Water'], dtype=object)

# %% [markdown]
# Define conditions for when shots were hit from the rough or fairway

# %%
data['is_rough'] =  ~data['FromLocation(Scorer)'].isna() & data['FromLocation(Scorer)'].str.contains('Rough')

# %%
data['is_fairway'] =  ~data['FromLocation(Enhanced)'].isna() & ( data['FromLocation(Enhanced)'].str.contains('Fairway') |  data['FromLocation(Enhanced)'].str.contains('Enhanced') )

# %% [markdown]
# Filter out shots where no distance information (and thus no strokes gained) was recorded

# %%
data = data[data.DistancetoPin > 0]

# %% [markdown]
# Filter out tournaments with invalid data:

# %%
# Remove pair tournament with invalid data
data = data[data['TournamentName'] != 'Zurich Classic of New Orleans']
#Remove match play tournament
data = data[~data['TournamentName'].str.contains('Match Play')]

# %% [markdown]
# Create separate dataframes for shots:

# %%
rough_shots = data[data['is_rough']]
fairway_shots = data[data['is_fairway']]

# %% [markdown]
# Calculate stats for the two dataframes:

# %%
rough_sg = rough_shots.groupby('CourseName').describe()['StrokesGained/Baseline'][['mean', 'count', 'std']]

# %%
fairway_sg = fairway_shots.groupby('CourseName').describe()['StrokesGained/Baseline'][['mean', 'count', 'std']]

# %% [markdown]
# Combine dataframes:

# %%
sg_mean = pd.concat((fairway_sg, rough_sg), axis=1)

# %%
sg_mean.columns = ['fairway_mean', 'fairway_count', 'fairway_std', 'rough_mean', 'rough_count', 'rough_std']

# %% [markdown]
# Normalize around mean of all rought/fairway shots. The mean should be 0 since strokes gained is calculated against a baseline, but depending on playing conditions over a season it may deviate.

# %%
all_rough_mean = rough_shots['StrokesGained/Baseline'].mean()
all_fairway_mean = fairway_shots['StrokesGained/Baseline'].mean()
sg_mean['rough_mean'] = sg_mean['rough_mean'] - all_rough_mean
sg_mean['fairway_mean'] = sg_mean['fairway_mean'] - all_fairway_mean
sg_mean['diff'] = sg_mean['rough_mean'] - sg_mean['fairway_mean']

# %%
import scipy.stats as stats

# %% [markdown]
# ## Two sample t-test
# Using a two sample t-test, we can calculate p-value for the zero hypothesis that the rough and fairway difficulty are equal (compared to baseline for each lie type). We can then compare this p-value against our desired signifcance level (0.05). We can do this since the samples are so large that the distribution of the means is approximately normal. Since we do not assume equal variances for the two populations (rough and fairway shots), we use [Welch's t-test](https://en.wikipedia.org/wiki/Welch%27s_t-test). This is applied using the scipy.stats library.

# %%
def two_sample_ttest(row):
    statistic, p_val = stats.ttest_ind_from_stats(row['fairway_mean'],
                                                  row['fairway_std'],
                                                  row['fairway_count'],
                                                  row['rough_mean'],
                                                  row['rough_std'],
                                                  row['rough_count'],
                                                  equal_var = False)
    return p_val

sg_mean['p_val'] = sg_mean.apply(two_sample_ttest, axis=1)

# %% [markdown]
# Compare p-values against a significance level of 0.05:

# %%
alpha = 0.05
sg_mean['significant'] = sg_mean['p_val'] < alpha

# %% [markdown]
# ## Results
# Plot courses by difference in difficulty between rough and fairway. Courses at the top are harder from the rough than fairway (compared to baseline, as rough shots are almost always more difficult than fairway shots from an absolute standpoint).

# %%
sg_mean.sort_values('diff')
# Out:
#                                 fairway_mean  fairway_count  fairway_std  \
# CourseName
# East Lake GC                        0.066558         1156.0     0.330997
# Muirfield Village GC                0.019699         5070.0     0.383432
# Bellerive CC                        0.046180         6055.0     0.320330
# TPC Southwind                       0.012856         4885.0     0.346411
# TPC Potomac at Avenel Farm          0.044356         4198.0     0.357672
# TPC Deere Run                       0.032486         5974.0     0.358393
# Sedgefield CC                       0.047420         5119.0     0.331337
# Bay Hill Club & Lodge              -0.016071         5746.0     0.351686
# Ridgewood CC                        0.021153         5020.0     0.326354
# Firestone CC (South)                0.024789         2667.0     0.353075
# Waialae CC                          0.045592         4467.0     0.325012
# Colonial CC                         0.015170         4143.0     0.360431
# TPC River Highlands                -0.010181         5697.0     0.359491
# The Old White TPC                   0.048465         5158.0     0.318778
# Aronimink GC                        0.034447         3420.0     0.321748
# TPC Boston                          0.011482         4269.0     0.363061
# Keene Trace Golf Club               0.037627         4772.0     0.358606
# Torrey Pines GC (South)            -0.015019         3113.0     0.345696
# Sea Island Resort (Seaside)        -0.008584         4038.0     0.328059
# TPC Sawgrass                       -0.011107         5605.0     0.362222
# Club de Golf Chapultepec            0.027049         2500.0     0.358221
# TPC Scottsdale                     -0.000070         4450.0     0.357129
# Silverado Resort and Spa North     -0.024840         4532.0     0.338555
# Stadium Course                      0.008013         2451.0     0.352833
# Innisbrook Resort (Copperhead)     -0.030476         4699.0     0.324834
# CC of Jackson                      -0.034930         5005.0     0.327054
# Glen Abbey GC                      -0.030789         4583.0     0.396810
# Quail Hollow Club                  -0.031327         5005.0     0.348048
# PGA National (Champion)            -0.059454         5025.0     0.376066
# Plantation Course at Kapalua       -0.034521         1826.0     0.366888
# TPC Summerlin                      -0.069025         5084.0     0.375889
# Pebble Beach GL                    -0.056727         2940.0     0.367628
# Trinity Forest Golf Club            0.015791         7278.0     0.339246
# Riviera CC                         -0.022414         5267.0     0.339155
# TPC San Antonio - AT&T Oaks        -0.063312         5878.0     0.358134
# Harbour Town GL                    -0.014689         5793.0     0.351637
# GC of Houston                       0.016653         5884.0     0.333841
#
#                                 rough_mean  rough_count  rough_std      diff  \
# CourseName
# East Lake GC                     -0.059045       1042.0   0.338802 -0.125603
# Muirfield Village GC             -0.054591       2977.0   0.386643 -0.074290
# Bellerive CC                     -0.027218       2590.0   0.360528 -0.073398
# TPC Southwind                    -0.057463       4077.0   0.381274 -0.070319
# TPC Potomac at Avenel Farm       -0.015418       3132.0   0.359574 -0.059773
# TPC Deere Run                    -0.026956       2575.0   0.354337 -0.059442
# Sedgefield CC                    -0.006151       3117.0   0.349761 -0.053571
# Bay Hill Club & Lodge            -0.065948       1893.0   0.370427 -0.049877
# Ridgewood CC                     -0.017918       2859.0   0.338498 -0.039071
# Firestone CC (South)             -0.013633       2979.0   0.365690 -0.038422
# Waialae CC                        0.017050       2877.0   0.351160 -0.028543
# Colonial CC                      -0.013320       2955.0   0.385437 -0.028490
# TPC River Highlands              -0.036022       2627.0   0.374326 -0.025842
# The Old White TPC                 0.022655       3371.0   0.342457 -0.025811
# Aronimink GC                      0.009701       1443.0   0.351265 -0.024746
# TPC Boston                       -0.008891       2239.0   0.387499 -0.020373
# Keene Trace Golf Club             0.026245       3386.0   0.382209 -0.011382
# Torrey Pines GC (South)          -0.021252       3265.0   0.344740 -0.006233
# Sea Island Resort (Seaside)      -0.009678       1321.0   0.364662 -0.001094
# TPC Sawgrass                     -0.011330       2249.0   0.400910 -0.000224
# Club de Golf Chapultepec          0.039372       2593.0   0.370504  0.012323
# TPC Scottsdale                    0.013874       2632.0   0.359486  0.013944
# Silverado Resort and Spa North   -0.010569       4306.0   0.342899  0.014272
# Stadium Course                    0.024499       2652.0   0.383602  0.016486
# Innisbrook Resort (Copperhead)   -0.009847       4197.0   0.328367  0.020629
# CC of Jackson                    -0.004539       3756.0   0.347239  0.030392
# Glen Abbey GC                     0.005126       4600.0   0.376443  0.035915
# Quail Hollow Club                 0.012688       3811.0   0.355003  0.044015
# PGA National (Champion)          -0.015214       3572.0   0.380834  0.044240
# Plantation Course at Kapalua      0.011195        964.0   0.362235  0.045716
# TPC Summerlin                    -0.017231       3510.0   0.389341  0.051794
# Pebble Beach GL                   0.002458       1596.0   0.378693  0.059184
# Trinity Forest Golf Club          0.076934        699.0   0.352778  0.061143
# Riviera CC                        0.052232       3890.0   0.351422  0.074646
# TPC San Antonio - AT&T Oaks       0.028054       3212.0   0.376039  0.091366
# Harbour Town GL                   0.085013       2194.0   0.384937  0.099702
# GC of Houston                     0.128316       2420.0   0.366181  0.111662
#
#                                        p_val  significant
# CourseName
# East Lake GC                    3.431573e-18         True
# Muirfield Village GC            8.558370e-17         True
# Bellerive CC                    4.775592e-19         True
# TPC Southwind                   1.581681e-19         True
# TPC Potomac at Avenel Farm      1.880642e-12         True
# TPC Deere Run                   1.514008e-12         True
# Sedgefield CC                   6.730312e-12         True
# Bay Hill Club & Lodge           2.855011e-07         True
# Ridgewood CC                    6.196614e-07         True
# Firestone CC (South)            6.052872e-05         True
# Waialae CC                      4.689594e-04         True
# Colonial CC                     1.622388e-03         True
# TPC River Highlands             3.053173e-03         True
# The Old White TPC               4.743810e-04         True
# Aronimink GC                    2.153904e-02         True
# TPC Boston                      3.959241e-02         True
# Keene Trace Golf Club           1.740350e-01        False
# Torrey Pines GC (South)         4.710896e-01        False
# Sea Island Resort (Seaside)     9.227703e-01        False
# TPC Sawgrass                    9.816829e-01        False
# Club de Golf Chapultepec        2.275643e-01        False
# TPC Scottsdale                  1.138675e-01        False
# Silverado Resort and Spa North  4.911418e-02         True
# Stadium Course                  1.098519e-01        False
# Innisbrook Resort (Copperhead)  2.956656e-03         True
# CC of Jackson                   3.271553e-05         True
# Glen Abbey GC                   8.724983e-06         True
# Quail Hollow Club               6.252194e-09         True
# PGA National (Champion)         9.794160e-08         True
# Plantation Course at Kapalua    1.623819e-03         True
# TPC Summerlin                   8.268301e-10         True
# Pebble Beach GL                 4.026810e-07         True
# Trinity Forest Golf Club        1.272364e-05         True
# Riviera CC                      2.849098e-24         True
# TPC San Antonio - AT&T Oaks     3.922519e-29         True
# Harbour Town GL                 9.085112e-26         True
# GC of Houston                   1.246119e-37         True

# %% [markdown]
# The site of the Tour Championship, East Lake, has a clear lead at the top. This is not surprising as that course is famous for it's difficult rough, and I believe our favourite scientist golfer [Bryson Dechambeau would agree](https://www.golfchannel.com/article/golf-central-blog/dechambeau-rough-never-encountered-something-thick)!
